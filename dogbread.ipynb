# %%
pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 491.0 kB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from kaggle) (1.16.0)
# Collecting certifi
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Requirement already satisfied: python-dateutil in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from kaggle) (2.8.2)
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting tqdm
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Collecting python-slugify
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Collecting urllib3
#   Downloading urllib3-2.0.4-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 2.3 MB/s eta 0:00:0000:01
# Collecting bleach
#   Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 954.7 kB/s eta 0:00:00a 0:00:01
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 940.9 kB/s eta 0:00:00 0:00:01
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.2.0-cp310-cp310-macosx_11_0_arm64.whl (124 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Installing collected packages: webencodings, text-unidecode, urllib3, tqdm, python-slugify, idna, charset-normalizer, certifi, bleach, requests, kaggle
#   DEPRECATION: kaggle is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for kaggle ... done
# Successfully installed bleach-6.0.0 certifi-2023.7.22 charset-normalizer-3.2.0 idna-3.4 kaggle-1.5.16 python-slugify-8.0.1 requests-2.31.0 text-unidecode-1.3 tqdm-4.66.1 urllib3-2.0.4 webencodings-0.5.1
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import kaggle
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/pawanipubudika/.kaggle/kaggle.json'

# %%
kaggle.api.dataset_download_files('catherinehorng/dogbreedidfromcomp', unzip=True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.13.0-cp310-cp310-macosx_12_0_arm64.whl (1.9 kB)
# Collecting tensorflow-macos==2.13.0
#   Using cached tensorflow_macos-2.13.0-cp310-cp310-macosx_12_0_arm64.whl (189.3 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: packaging in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (23.1)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.15.0-cp310-cp310-macosx_11_0_arm64.whl (36 kB)
# Collecting tensorflow-estimator<2.14,>=2.13.0
#   Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.57.0-cp310-cp310-macosx_12_0_universal2.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 242.9 kB/s eta 0:00:0000:0100:01
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorboard<2.14,>=2.13
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.9.0-cp310-cp310-macosx_11_0_arm64.whl (2.7 MB)
# Requirement already satisfied: six>=1.12.0 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: setuptools in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (65.5.0)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl (20.6 MB)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from tensorflow-macos==2.13.0->tensorflow) (2.13.1)
# Collecting numpy<=1.24.3,>=1.22
#   Using cached numpy-1.24.3-cp310-cp310-macosx_11_0_arm64.whl (13.9 MB)
# Collecting flatbuffers>=23.1.21
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting typing-extensions<4.6.0,>=3.6.6
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.24.1-cp37-abi3-macosx_10_9_universal2.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 343.0 kB/s eta 0:00:0000:0100:01
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.41.1-py3-none-any.whl (64 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2.31.0)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-2.3.7-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.2/242.2 kB 201.4 kB/s eta 0:00:00a 0:00:01
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.4-py3-none-any.whl (94 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting urllib3<2.0
#   Using cached urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow) (2023.7.22)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.3-cp310-cp310-macosx_10_9_universal2.whl (17 kB)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: libclang, flatbuffers, wrapt, wheel, urllib3, typing-extensions, termcolor, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, MarkupSafe, markdown, grpcio, google-pasta, gast, cachetools, absl-py, werkzeug, rsa, pyasn1-modules, opt-einsum, h5py, astunparse, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-macos, tensorflow
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# Successfully installed MarkupSafe-2.1.3 absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.1 flatbuffers-23.5.26 gast-0.4.0 google-auth-2.22.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.57.0 h5py-3.9.0 libclang-16.0.6 markdown-3.4.4 numpy-1.24.3 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.24.1 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-macos-2.13.0 termcolor-2.3.0 typing-extensions-4.5.0 urllib3-1.26.16 werkzeug-2.3.7 wheel-0.41.1 wrapt-1.15.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.3.0-cp310-cp310-macosx_12_0_arm64.whl (9.5 MB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from scikit-learn) (1.24.3)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting scipy>=1.5.0
#   Downloading scipy-1.11.2-cp310-cp310-macosx_12_0_arm64.whl (29.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.6/29.6 MB 1.2 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.0 scipy-1.11.2 threadpoolctl-3.2.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import Adam

# %%
labels_all = pd.read_csv("/Users/pawanipubudika/Documents/ready/Dog bread prediction/src/labels.csv")
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
breeds_all = labels_all["breed"]
breed_counts = breeds_all.value_counts()
breed_counts.head()
# Out:
# breed
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: count, dtype: int64

# %%
CLASS_NAMES= ["scottish_deerhound","maltese_dog","bernese_mountain_dog"]
labels=labels_all[(labels_all["breed"].isin(CLASS_NAMES))]
labels=labels.reset_index()
labels.head()
# Out:
#    index                                id                 breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64    scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec           maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44    scottish_deerhound
# 3     90  022b34fd8734b39995a9f38a4f3e7b6b           maltese_dog
# 4    118  02d54f0dfb40038765e838459ae8c956  bernese_mountain_dog

# %%
import os

# %%
image_directory = '/Users/pawanipubudika/Documents/ready/Dog_bread_prediction/src/train/'

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAMES)
# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    image_path = os.path.join(image_directory, labels['id'][i] + '.jpg')
    img = image.load_img(image_path, target_size=(224, 224))
    img = image.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0
    
# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|██████████| 357/357 [00:00<00:00, 663.58it/s]
# Train Images shape:  (357, 224, 224, 3)  size: 53,738,496
# One-hot encoded output shape:  (357, 3)  size: 1,071

# %%
# Building the Model
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAMES), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 220, 220, 64)      4864
#
#  max_pooling2d_4 (MaxPoolin  (None, 110, 110, 64)      0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 108, 108, 32)      18464
#
#  max_pooling2d_5 (MaxPoolin  (None, 54, 54, 32)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 48, 48, 16)        25104
#
#  max_pooling2d_6 (MaxPoolin  (None, 24, 24, 16)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 20, 20, 8)         3208
#
#  max_pooling2d_7 (MaxPoolin  (None, 10, 10, 8)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  dense_3 (Dense)             (None, 128)               102528
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 162619 (635.23 KB)
# Trainable params: 162619 (635.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %%
# Training the model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (X_val, Y_val))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 8s 3s/step - loss: 4.9018 - accuracy: 0.3789 - val_loss: 4.8764 - val_accuracy: 0.5231
# Epoch 2/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.8754 - accuracy: 0.4180 - val_loss: 4.8513 - val_accuracy: 0.5231
# Epoch 3/100
# 2/2 [==============================] - 7s 4s/step - loss: 4.8496 - accuracy: 0.4219 - val_loss: 4.8243 - val_accuracy: 0.5385
# Epoch 4/100
# 2/2 [==============================] - 7s 3s/step - loss: 4.8237 - accuracy: 0.4180 - val_loss: 4.7971 - val_accuracy: 0.5385
# Epoch 5/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.7975 - accuracy: 0.4258 - val_loss: 4.7708 - val_accuracy: 0.5692
# Epoch 6/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.7708 - accuracy: 0.4531 - val_loss: 4.7445 - val_accuracy: 0.5846
# Epoch 7/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.7440 - accuracy: 0.4648 - val_loss: 4.7168 - val_accuracy: 0.5846
# Epoch 8/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.7172 - accuracy: 0.4688 - val_loss: 4.6880 - val_accuracy: 0.5692
# Epoch 9/100
# 2/2 [==============================] - 7s 4s/step - loss: 4.6893 - accuracy: 0.4961 - val_loss: 4.6590 - val_accuracy: 0.5846
# Epoch 10/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.6609 - accuracy: 0.5156 - val_loss: 4.6284 - val_accuracy: 0.5538
# Epoch 11/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.6310 - accuracy: 0.5312 - val_loss: 4.5976 - val_accuracy: 0.6154
# Epoch 12/100
# 2/2 [==============================] - 7s 3s/step - loss: 4.5998 - accuracy: 0.5938 - val_loss: 4.5655 - val_accuracy: 0.6000
# Epoch 13/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.5660 - accuracy: 0.5977 - val_loss: 4.5304 - val_accuracy: 0.6462
# Epoch 14/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.5297 - accuracy: 0.5977 - val_loss: 4.4936 - val_accuracy: 0.6615
# Epoch 15/100
# 2/2 [==============================] - 7s 3s/step - loss: 4.4930 - accuracy: 0.5977 - val_loss: 4.4558 - val_accuracy: 0.6923
# Epoch 16/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.4532 - accuracy: 0.6016 - val_loss: 4.4194 - val_accuracy: 0.6769
# Epoch 17/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.4101 - accuracy: 0.6211 - val_loss: 4.3743 - val_accuracy: 0.6615
# Epoch 18/100
# 2/2 [==============================] - 7s 3s/step - loss: 4.3697 - accuracy: 0.6172 - val_loss: 4.3248 - val_accuracy: 0.6615
# Epoch 19/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.3229 - accuracy: 0.6367 - val_loss: 4.2918 - val_accuracy: 0.7385
# Epoch 20/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.2792 - accuracy: 0.6367 - val_loss: 4.2349 - val_accuracy: 0.7077
# Epoch 21/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.2367 - accuracy: 0.6406 - val_loss: 4.1816 - val_accuracy: 0.6462
# Epoch 22/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.1906 - accuracy: 0.6523 - val_loss: 4.1685 - val_accuracy: 0.6923
# Epoch 23/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.1514 - accuracy: 0.6406 - val_loss: 4.1238 - val_accuracy: 0.6923
# Epoch 24/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.1085 - accuracy: 0.6641 - val_loss: 4.0666 - val_accuracy: 0.6923
# Epoch 25/100
# 2/2 [==============================] - 6s 3s/step - loss: 4.0769 - accuracy: 0.6680 - val_loss: 4.0365 - val_accuracy: 0.7231
# Epoch 26/100
# 2/2 [==============================] - 7s 4s/step - loss: 4.0366 - accuracy: 0.6719 - val_loss: 4.0084 - val_accuracy: 0.7077
# Epoch 27/100
# 2/2 [==============================] - 63s 4s/step - loss: 4.0013 - accuracy: 0.6758 - val_loss: 3.9882 - val_accuracy: 0.7077
# Epoch 28/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.9771 - accuracy: 0.6836 - val_loss: 3.9407 - val_accuracy: 0.6923
# Epoch 29/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.9365 - accuracy: 0.7188 - val_loss: 3.9156 - val_accuracy: 0.6923
# Epoch 30/100
# 2/2 [==============================] - 114s 3s/step - loss: 3.9046 - accuracy: 0.7109 - val_loss: 3.8986 - val_accuracy: 0.7077
# Epoch 31/100
# 2/2 [==============================] - 641s 4s/step - loss: 3.8814 - accuracy: 0.7031 - val_loss: 3.8702 - val_accuracy: 0.7077
# Epoch 32/100
# 2/2 [==============================] - 8s 4s/step - loss: 3.8445 - accuracy: 0.7422 - val_loss: 3.8226 - val_accuracy: 0.7538
# Epoch 33/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.8198 - accuracy: 0.7305 - val_loss: 3.7958 - val_accuracy: 0.7692
# Epoch 34/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.7930 - accuracy: 0.7227 - val_loss: 3.7860 - val_accuracy: 0.7385
# Epoch 35/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.7677 - accuracy: 0.7461 - val_loss: 3.7655 - val_accuracy: 0.7538
# Epoch 36/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.7449 - accuracy: 0.7461 - val_loss: 3.7245 - val_accuracy: 0.7692
# Epoch 37/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.7293 - accuracy: 0.7500 - val_loss: 3.7038 - val_accuracy: 0.8000
# Epoch 38/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.7128 - accuracy: 0.7422 - val_loss: 3.7121 - val_accuracy: 0.8000
# Epoch 39/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.7314 - accuracy: 0.7305 - val_loss: 3.7066 - val_accuracy: 0.8000
# Epoch 40/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.6841 - accuracy: 0.7422 - val_loss: 3.6909 - val_accuracy: 0.7538
# Epoch 41/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.6748 - accuracy: 0.7500 - val_loss: 3.6391 - val_accuracy: 0.7846
# Epoch 42/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.6492 - accuracy: 0.7734 - val_loss: 3.6341 - val_accuracy: 0.7846
# Epoch 43/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.6010 - accuracy: 0.7852 - val_loss: 3.6751 - val_accuracy: 0.7692
# Epoch 44/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.6092 - accuracy: 0.7578 - val_loss: 3.6296 - val_accuracy: 0.7692
# Epoch 45/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.5864 - accuracy: 0.7734 - val_loss: 3.5712 - val_accuracy: 0.7692
# Epoch 46/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.5835 - accuracy: 0.7930 - val_loss: 3.5627 - val_accuracy: 0.7846
# Epoch 47/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.5494 - accuracy: 0.7930 - val_loss: 3.5591 - val_accuracy: 0.7846
# Epoch 48/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.5279 - accuracy: 0.7852 - val_loss: 3.5827 - val_accuracy: 0.7846
# Epoch 49/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.5103 - accuracy: 0.7930 - val_loss: 3.5702 - val_accuracy: 0.7538
# Epoch 50/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.4943 - accuracy: 0.8125 - val_loss: 3.5035 - val_accuracy: 0.7846
# Epoch 51/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.4743 - accuracy: 0.7969 - val_loss: 3.4910 - val_accuracy: 0.7846
# Epoch 52/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.4574 - accuracy: 0.8047 - val_loss: 3.5157 - val_accuracy: 0.8000
# Epoch 53/100
# 2/2 [==============================] - 7s 3s/step - loss: 3.4374 - accuracy: 0.8242 - val_loss: 3.5185 - val_accuracy: 0.7692
# Epoch 54/100
# 2/2 [==============================] - 7s 3s/step - loss: 3.4253 - accuracy: 0.8281 - val_loss: 3.4767 - val_accuracy: 0.8000
# Epoch 55/100
# 2/2 [==============================] - 8s 4s/step - loss: 3.4157 - accuracy: 0.8164 - val_loss: 3.4548 - val_accuracy: 0.7846
# Epoch 56/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.3920 - accuracy: 0.8203 - val_loss: 3.4599 - val_accuracy: 0.8308
# Epoch 57/100
# 2/2 [==============================] - 7s 3s/step - loss: 3.3804 - accuracy: 0.8164 - val_loss: 3.4558 - val_accuracy: 0.8000
# Epoch 58/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.3759 - accuracy: 0.8086 - val_loss: 3.4387 - val_accuracy: 0.7846
# Epoch 59/100
# 2/2 [==============================] - 7s 3s/step - loss: 3.3535 - accuracy: 0.8438 - val_loss: 3.4262 - val_accuracy: 0.8308
# Epoch 60/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.3533 - accuracy: 0.8164 - val_loss: 3.4186 - val_accuracy: 0.7846
# Epoch 61/100
# 2/2 [==============================] - 7s 3s/step - loss: 3.3172 - accuracy: 0.8281 - val_loss: 3.4178 - val_accuracy: 0.8154
# Epoch 62/100
# 2/2 [==============================] - 7s 3s/step - loss: 3.3004 - accuracy: 0.8438 - val_loss: 3.4030 - val_accuracy: 0.8154
# Epoch 63/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.2849 - accuracy: 0.8594 - val_loss: 3.3898 - val_accuracy: 0.8000
# Epoch 64/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.2717 - accuracy: 0.8477 - val_loss: 3.3769 - val_accuracy: 0.8154
# Epoch 65/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.2594 - accuracy: 0.8359 - val_loss: 3.3805 - val_accuracy: 0.8000
# Epoch 66/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.2423 - accuracy: 0.8594 - val_loss: 3.3690 - val_accuracy: 0.8000
# Epoch 67/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.2354 - accuracy: 0.8438 - val_loss: 3.3414 - val_accuracy: 0.8154
# Epoch 68/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.2195 - accuracy: 0.8516 - val_loss: 3.3628 - val_accuracy: 0.8308
# Epoch 69/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.2029 - accuracy: 0.8555 - val_loss: 3.3411 - val_accuracy: 0.7846
# Epoch 70/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.1940 - accuracy: 0.8320 - val_loss: 3.3210 - val_accuracy: 0.7846
# Epoch 71/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.1834 - accuracy: 0.8516 - val_loss: 3.3344 - val_accuracy: 0.8154
# Epoch 72/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.1637 - accuracy: 0.8516 - val_loss: 3.3525 - val_accuracy: 0.7846
# Epoch 73/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.1542 - accuracy: 0.8398 - val_loss: 3.3105 - val_accuracy: 0.8154
# Epoch 74/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.1414 - accuracy: 0.8672 - val_loss: 3.2979 - val_accuracy: 0.8154
# Epoch 75/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.1215 - accuracy: 0.8672 - val_loss: 3.3168 - val_accuracy: 0.7692
# Epoch 76/100
# 2/2 [==============================] - 6s 4s/step - loss: 3.1110 - accuracy: 0.8789 - val_loss: 3.2959 - val_accuracy: 0.8154
# Epoch 77/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.0945 - accuracy: 0.8828 - val_loss: 3.2805 - val_accuracy: 0.7846
# Epoch 78/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.0839 - accuracy: 0.8555 - val_loss: 3.2790 - val_accuracy: 0.7846
# Epoch 79/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.0683 - accuracy: 0.8750 - val_loss: 3.2906 - val_accuracy: 0.8000
# Epoch 80/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.0599 - accuracy: 0.8750 - val_loss: 3.2630 - val_accuracy: 0.8000
# Epoch 81/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.0385 - accuracy: 0.8828 - val_loss: 3.2511 - val_accuracy: 0.8154
# Epoch 82/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.0295 - accuracy: 0.8789 - val_loss: 3.2560 - val_accuracy: 0.7846
# Epoch 83/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.0175 - accuracy: 0.8711 - val_loss: 3.2632 - val_accuracy: 0.8154
# Epoch 84/100
# 2/2 [==============================] - 6s 3s/step - loss: 3.0038 - accuracy: 0.8828 - val_loss: 3.2455 - val_accuracy: 0.8154
# Epoch 85/100
# 2/2 [==============================] - 7s 4s/step - loss: 2.9956 - accuracy: 0.8711 - val_loss: 3.2341 - val_accuracy: 0.7846
# Epoch 86/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.9766 - accuracy: 0.8867 - val_loss: 3.2332 - val_accuracy: 0.8154
# Epoch 87/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.9839 - accuracy: 0.8828 - val_loss: 3.2349 - val_accuracy: 0.7846
# Epoch 88/100
# 2/2 [==============================] - 7s 4s/step - loss: 2.9514 - accuracy: 0.8828 - val_loss: 3.2263 - val_accuracy: 0.8154
# Epoch 89/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.9434 - accuracy: 0.8828 - val_loss: 3.2082 - val_accuracy: 0.8000
# Epoch 90/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.9286 - accuracy: 0.8945 - val_loss: 3.2108 - val_accuracy: 0.8154
# Epoch 91/100
# 2/2 [==============================] - 6s 4s/step - loss: 2.9177 - accuracy: 0.9023 - val_loss: 3.2201 - val_accuracy: 0.8154
# Epoch 92/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.9005 - accuracy: 0.9023 - val_loss: 3.1971 - val_accuracy: 0.8000
# Epoch 93/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.8942 - accuracy: 0.8906 - val_loss: 3.1916 - val_accuracy: 0.8154
# Epoch 94/100
# 2/2 [==============================] - 7s 4s/step - loss: 2.8840 - accuracy: 0.8906 - val_loss: 3.2026 - val_accuracy: 0.8154
# Epoch 95/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.8663 - accuracy: 0.8984 - val_loss: 3.1746 - val_accuracy: 0.8000
# Epoch 96/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.8574 - accuracy: 0.8906 - val_loss: 3.1691 - val_accuracy: 0.7846
# Epoch 97/100
# 2/2 [==============================] - 6s 4s/step - loss: 2.8459 - accuracy: 0.8984 - val_loss: 3.1897 - val_accuracy: 0.8154
# Epoch 98/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.8361 - accuracy: 0.9023 - val_loss: 3.1918 - val_accuracy: 0.8000
# Epoch 99/100
# 2/2 [==============================] - 6s 3s/step - loss: 2.8275 - accuracy: 0.8945 - val_loss: 3.1557 - val_accuracy: 0.7846
# Epoch 100/100
# 2/2 [==============================] - 6s 4s/step - loss: 2.8318 - accuracy: 0.9023 - val_loss: 3.1540 - val_accuracy: 0.8000

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 23ms/step - loss: 3.1335 - accuracy: 0.7778
# Accuracy over the test set:
#   77.78 %

# %%
# Plotting image to compare
plt.imshow(X_test[3,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[5])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[5])])
# Out:
# Originally :  scottish_deerhound
# Predicted :  scottish_deerhound

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: pandas>=0.25 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.42.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

# %%
model.save("dog_breed.h5")
# Out:
# /Users/pawanipubudika/Documents/ready/Dog bread prediction/tf_env/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
